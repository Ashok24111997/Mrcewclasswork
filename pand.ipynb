# %%
import pandas as pd

# %%
df = pd.read_csv("The Titanic dataset.csv",header=1)
df
# Out:
#         sn  pclass  survived                              Unnamed: 3  gender  \
# 0        1       3         0                             Mr. Anthony    male
# 1        1       3         0                             Mr. Anthony    male
# 2        2       3         0                   Master. Eugene Joseph    male
# 3        3       2         0             Abbott, Mr. Rossmore Edward     NaN
# 4        4       3         1             Abbott, Mr. Rossmore Edward  female
# ...    ...     ...       ...                                     ...     ...
# 1296  1296       2         0  Yrois, Miss. Henriette ("Mrs Harbeck")  female
# 1297  1297       3         0                    Zabour, Miss. Hileni  female
# 1298  1298       3         0               Zakarian, Mr. Mapriededer    male
# 1299  1299       3         0                     Zakarian, Mr. Ortin    male
# 1300  1300       3         0                      Zimmerman, Mr. Leo    male
#
# ...

# %%
df.columns[0]
# Out:
# 'sn'

# %%
df.columns
# Out:
# Index(['sn', 'pclass', 'survived', 'Unnamed: 3', 'gender', 'age', 'family',
#        'fare', 'embarked', 'date'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['sn', 'pclass', 'survived', 'Unnamed: 3', 'gender', 'age', 'family',
#        'fare', 'embarked', 'date'],
#       dtype='object')

# %%
print(df.shape)
# Out:
# (1301, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sn          1301 non-null   int64
#  1   pclass      1301 non-null   int64
#  2   survived    1301 non-null   int64
#  3   Unnamed: 3  1301 non-null   object
#  4   gender      1300 non-null   object
#  5   age         1044 non-null   object
#  6   family      1299 non-null   float64
#  7   fare        1299 non-null   object
#  8   embarked    1295 non-null   object
#  9   date        1301 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 101.8+ KB

# %%
df.describe()
# Out:
#                 sn       pclass     survived       family
# count  1301.000000  1301.000000  1301.000000  1299.000000
# mean    650.000769     2.289777     0.384320     0.889915
# std     375.709330     0.838384     0.486621     1.588008
# min       1.000000     1.000000     0.000000     0.000000
# 25%     325.000000     2.000000     0.000000     0.000000
# 50%     650.000000     3.000000     0.000000     0.000000
# 75%     975.000000     3.000000     1.000000     1.000000
# max    1300.000000     3.000000     1.000000    10.000000

# %% [markdown]
# what is loc and iloc

# %%
df.loc[1:4]
# Out:
#    sn  pclass  survived                   Unnamed: 3  gender  age  family  \
# 1   1       3         0                  Mr. Anthony    male   42     0.0
# 2   2       3         0        Master. Eugene Joseph    male    ?     2.0
# 3   3       2         0  Abbott, Mr. Rossmore Edward     NaN  NaN     2.0
# 4   4       3         1  Abbott, Mr. Rossmore Edward  female   35     2.0
#
#     fare embarked       date
# 1   7.55      NaN  01-Jan-90
# 2  20.25        S  02-Jan-90
# 3     **        S  03-Jan-90
# 4  20.25        S  04-Jan-90

# %%
a=df.loc[1:3, ["age", "gender"]]
a
# Out:
#    age gender
# 1   42   male
# 2    ?   male
# 3  NaN    NaN

# %%
a=df.loc[:, ["gender","age"]]

# %%
b = a[a["age"] > 30]
b
# Out:
#       gender   age
# 0       male  42.0
# 1       male  42.0
# 4     female  35.0
# 13    female  40.0
# 23      male  35.0
# ...      ...   ...
# 1285  female  31.0
# 1288    male  36.0
# 1291    male  62.0
# 1294  female  36.0
# 1295    male  45.5
#
# [438 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# sn              0
# pclass          0
# survived        0
# Unnamed: 3      0
# gender          1
# age           257
# family          2
# fare            2
# embarked        6
# date            0
# dtype: int64

# %%
print(df["age"].unique())
# Out:
# ['42' '?' nan '35' '16' '25' '30' '28' '20' '18' '26' '40' '0.83' '24'
#  '29' '0.92' '2' '32' '19' '48' '4' '6' '17' '38' '9' '11' '39' '27' '63'
#  '34' '36' '53' '71' '57' '5' '3' '13' '23' '45' '21' '47' '33' '0.75'
#  '80' '22' '51' '50' '1' '12' '37' '58' '41' '15' '60' '44' '59' '18.5'
#  '14' '54' '49' '76' '46' '52' '8' '31' '64' '70.5' '43' '55' '70' '22.5'
#  '36.5' '65' '40.5' '10' '0.67' '23.5' '62' '7' '32.5' '34.5' '61' '20.5'
#  '30.5' '55.5' '0.17' '28.5' '45.5' '56' '38.5' '14.5' '24.5' '60.5' '67'
#  '74' '11.5' '66' '26.5']

# %%
df["age"] = pd.to_numeric(df["age"], errors="coerce")

# %% [markdown]
# Data cleaning and fill null values

# %%
df.dtypes
# Out:
# sn              int64
# pclass          int64
# survived        int64
# Unnamed: 3     object
# gender         object
# age            object
# family        float64
# fare           object
# embarked       object
# date           object
# dtype: object

# %%
df["age"] = pd.to_numeric(df["age"], errors="coerce")

# %%
df.dtypes
# Out:
# sn              int64
# pclass          int64
# survived        int64
# Unnamed: 3     object
# gender         object
# age           float64
# family        float64
# fare           object
# embarked       object
# date           object
# dtype: object

# %%
df["age"]= df["age"].fillna(df["age"].mean())
a=df["age"].isnull().sum()
a
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# sn              int64
# pclass          int64
# survived        int64
# Unnamed: 3     object
# gender         object
# age           float64
# family        float64
# fare           object
# embarked       object
# date           object
# dtype: object

# %%
uni = df["fare"].unique()
uni
# Out:
# array(['7.55', '20.25', '**', '7.65', '24', '7.925', '7.2292', '7.25',
#        '8.05', '9.475', '9.35', '18.7875', '13', '7.8875', '7.05',
#        '211.3375', '151.55', '8.3', '22.525', '7.8542', '26.55', '31.275',
#        '7.775', '7.7958', '11.5', '10.5', '77.9583', '0', '7.8958', '26',
#        '51.4792', '17.8', '49.5042', '31.3875', '7.225', '227.525',
#        '14.4583', '69.3', '15.85', '19.2583', '14.4542', '78.85', '30',
#        '7.8792', '12.525', '25.925', '247.5208', '76.2917', '75.2417',
#        '39', '52.5542', '4.0125', '56.4958', '221.7792', '91.0792',
#        '135.6333', '7.75', '35.5', '31', '164.8667', '15.2458', '15.5',
#        '262.375', '16.1', '55', '7.725', '30.5', '50.4958', '7.0458',
#        '39.6', '27.7208', '7.2833', '7.8208', '6.75', '134.5', '8.6625',
#        '26.2875', '29', '21', '27.4458', '512.3292', '5', '47.1', '120',
#        '61.175', '53.1', '13.5', '7.7333', '86.5', '29.7', '136.7792',
# ...

# %% [markdown]
# Change fare String into number

# %%
df["fare"] =pd.to_numeric(df["fare"],errors="coerce")

# %%
df.dtypes
# Out:
# sn              int64
# pclass          int64
# survived        int64
# Unnamed: 3     object
# gender         object
# age           float64
# family        float64
# fare          float64
# embarked       object
# date           object
# dtype: object

# %%
df.head(5)
# Out:
#    sn  pclass  survived                   Unnamed: 3  gender       age  \
# 0   1       3         0                  Mr. Anthony    male  42.00000
# 1   1       3         0                  Mr. Anthony    male  42.00000
# 2   2       3         0        Master. Eugene Joseph    male  29.97883
# 3   3       2         0  Abbott, Mr. Rossmore Edward     NaN  29.97883
# 4   4       3         1  Abbott, Mr. Rossmore Edward  female  35.00000
#
#    family   fare embarked       date
# 0     0.0   7.55      NaN  01-Jan-90
# 1     0.0   7.55      NaN  01-Jan-90
# 2     2.0  20.25        S  02-Jan-90
# 3     2.0    NaN        S  03-Jan-90
# 4     2.0  20.25        S  04-Jan-90

# %%
df.isnull().sum()
# Out:
# sn            0
# pclass        0
# survived      0
# Unnamed: 3    0
# gender        1
# age           0
# family        2
# fare          3
# embarked      6
# date          0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# sn            0
# pclass        0
# survived      0
# Unnamed: 3    0
# gender        0
# age           0
# family        0
# fare          0
# embarked      0
# date          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['sn', 'pclass', 'survived', 'Unnamed: 3', 'gender', 'age', 'family',
#        'fare', 'embarked', 'date'],
#       dtype='object')

# %% [markdown]
# Rename of the column

# %%
df.rename(columns={
    'Unnamed: 3':"name"
}, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19728\1595737742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df
# Out:
#         sn  pclass  survived                                    name  gender  \
# 2        2       3         0                   Master. Eugene Joseph    male
# 4        4       3         1             Abbott, Mr. Rossmore Edward  female
# 5        5       3         1             Abelseth, Miss. Karen Marie  female
# 6        6       3         1           Abelseth, Mr. Olaus Jorgensen    male
# 7        7       2         0                     Abelson, Mr. Samuel    male
# ...    ...     ...       ...                                     ...     ...
# 1296  1296       2         0  Yrois, Miss. Henriette ("Mrs Harbeck")  female
# 1297  1297       3         0                    Zabour, Miss. Hileni  female
# 1298  1298       3         0               Zakarian, Mr. Mapriededer    male
# 1299  1299       3         0                     Zakarian, Mr. Ortin    male
# 1300  1300       3         0                      Zimmerman, Mr. Leo    male
#
# ...

# %%
df["age"].unique()
# Out:
# array([29.9788303, 35.       , 16.       , 25.       , 30.       ,
#        28.       , 20.       , 18.       , 26.       , 40.       ,
#         0.83     , 24.       , 29.       ,  0.92     ,  2.       ,
#        32.       , 19.       , 48.       ,  4.       ,  6.       ,
#        17.       , 38.       ,  9.       , 11.       , 39.       ,
#        27.       , 63.       , 34.       , 36.       , 53.       ,
#        71.       , 57.       ,  5.       ,  3.       , 13.       ,
#        23.       , 45.       , 21.       , 47.       , 33.       ,
#         0.75     , 80.       , 22.       , 51.       , 50.       ,
#         1.       , 12.       , 37.       , 42.       , 58.       ,
#        41.       , 15.       , 60.       , 44.       , 59.       ,
#        18.5      , 14.       , 54.       , 49.       , 76.       ,
#        46.       , 52.       ,  8.       , 31.       , 64.       ,
#        70.5      , 43.       , 55.       , 70.       , 22.5      ,
# ...

# %% [markdown]
# create a new colum and add the value

# %%
import numpy as np

df["bonus"] = np.where(
    (df["age"] >= 20) & (df["age"] < 30), 10000,
    np.where(
        (df["age"] >= 30) & (df["age"] < 40), 15000,
        0
    )
)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19728\2916604988.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bonus"] = np.where(

# %%
import numpy as np

df["bonus"] = np.where(
    (df["age"] >= 20) & (df["age"] < 30), 10000,
    np.where(
        (df["age"] >= 30) & (df["age"] < 40), 15000,
        np.where(
            df["age"] > 40, 25000,
            0
        )
    )
)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19728\4178085014.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bonus"] = np.where(

# %%
df.head(5)
# Out:
#    sn  pclass  survived                           name  gender       age  \
# 2   2       3         0          Master. Eugene Joseph    male  29.97883
# 4   4       3         1    Abbott, Mr. Rossmore Edward  female  35.00000
# 5   5       3         1    Abelseth, Miss. Karen Marie  female  16.00000
# 6   6       3         1  Abelseth, Mr. Olaus Jorgensen    male  25.00000
# 7   7       2         0            Abelson, Mr. Samuel    male  30.00000
#
#    family   fare embarked       date  bonus
# 2     2.0  20.25        S  02-Jan-90  10000
# 4     2.0  20.25        S  04-Jan-90  15000
# 5     0.0   7.65        S  05-Jan-90      0
# 6     0.0   7.65        S  06-Jan-90  10000
# 7     1.0  24.00        C  07-Jan-90  15000

# %% [markdown]
# Change data type
# as.type(int)
# if the column having numeric then only possible
# if the data set having nan it is not possible

# %%
df["age"] = df["age"].astype(int)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19728\3261694546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["age"] = df["age"].astype(int)

# %%
df.head(5)
# Out:
#    sn  pclass  survived                           name  gender  age  family  \
# 2   2       3         0          Master. Eugene Joseph    male   29     2.0
# 4   4       3         1    Abbott, Mr. Rossmore Edward  female   35     2.0
# 5   5       3         1    Abelseth, Miss. Karen Marie  female   16     0.0
# 6   6       3         1  Abelseth, Mr. Olaus Jorgensen    male   25     0.0
# 7   7       2         0            Abelson, Mr. Samuel    male   30     1.0
#
#     fare embarked       date  bonus
# 2  20.25        S  02-Jan-90  10000
# 4  20.25        S  04-Jan-90  15000
# 5   7.65        S  05-Jan-90      0
# 6   7.65        S  06-Jan-90  10000
# 7  24.00        C  07-Jan-90  15000

# %%
#count numberof rows
count = df[df["age"] < 14].shape[0]
print(count)
# Out:
# 95

# %% [markdown]
# Find less than 14 age people details

# %%
#see the rows data
df[df["age"] < 14].head()
# Out:
#     sn  pclass  survived                                     name  gender  \
# 14  14       3         1                Aks, Master. Philip Frank    male
# 24  24       1         1           Allison, Master. Hudson Trevor    male
# 25  25       1         0             Allison, Miss. Helen Loraine  female
# 32  32       3         0  Andersson, Master. Sigvard Harald Elias    male
# 33  33       3         0       Andersson, Miss. Ebba Iris Alfrida  female
#
#     age  family     fare embarked       date  bonus
# 14    0     1.0    9.350        S  14-Jan-90      0
# 24    0     3.0  151.550        S  24-Jan-90      0
# 25    2     3.0  151.550        S  25-Jan-90      0
# 32    4     6.0   31.275        S  01-Feb-90      0
# 33    6     6.0   31.275        S  02-Feb-90      0

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of         sn  pclass  survived                                    name  gender  \
# 2        2       3         0                   Master. Eugene Joseph    male
# 4        4       3         1             Abbott, Mr. Rossmore Edward  female
# 5        5       3         1             Abelseth, Miss. Karen Marie  female
# 6        6       3         1           Abelseth, Mr. Olaus Jorgensen    male
# 7        7       2         0                     Abelson, Mr. Samuel    male
# ...    ...     ...       ...                                     ...     ...
# 1296  1296       2         0  Yrois, Miss. Henriette ("Mrs Harbeck")  female
# 1297  1297       3         0                    Zabour, Miss. Hileni  female
# 1298  1298       3         0               Zakarian, Mr. Mapriededer    male
# 1299  1299       3         0                     Zakarian, Mr. Ortin    male
# 1300  1300       3         0                      Zimmerman, Mr. Leo    male
#
# ...

# %% [markdown]
# duplicate value is there are not
# keep if used it will take other than 1

# %%
check duplicate is present or not

# %%
df[df.duplicated(subset=["age","name"],keep=False)]
# Out:
# Empty DataFrame
# Columns: [sn, pclass, survived, name, gender, age, family, fare, embarked, date, bonus]
# Index: []

# %%
df.duplicated(subset=["age", "name"]).sum()
# Out:
# np.int64(0)
